# %% [markdown]
# # DAC Codebook Analysis: Clean Codes Added from End
#
# This notebook analyzes codebooks by progressively replacing noisy codebooks with clean ones **starting from the last codebook**.
#
# **Pattern**: Variant N has last N codebooks from CLEAN, first (12-N) from NOISY
#
# - Variant 1: `[N, N, N, N, N, N, N, N, N, N, N, C]` (11 noisy, 1 clean at end)
# - Variant 2: `[N, N, N, N, N, N, N, N, N, N, C, C]` (10 noisy, 2 clean at end)
# - ...
# - Variant 12: `[C, C, C, C, C, C, C, C, C, C, C, C]` (all clean)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio, display, HTML
import os
import random
from pathlib import Path
import scipy.io.wavfile as wavfile

# Add parent directory to path for dac imports
import sys
sys.path.insert(0, '..')

import dac
from dac.utils import load_model

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Load DAC 16kHz model
model = load_model(model_type="16khz")
model = model.to(device)
model.eval()
print(f"Loaded DAC 16kHz model with {model.n_codebooks} codebooks")
# Out:
# /home/amanag/descript-audio-codec/.venv/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded DAC 16kHz model with 12 codebooks

# %%
# Load sample data - pick a random pair
sample_dir = Path("../sample_data")
clean_dir = sample_dir / "clean"
noise_dir = sample_dir / "noise"

# Get list of clean files
clean_files = list(clean_dir.glob("*.wav"))
random_clean = random.choice(clean_files)

# Find corresponding noisy file
base_name = random_clean.stem  # e.g., p249_290
noisy_file = list(noise_dir.glob(f"{base_name}*.wav"))[0]

print(f"Selected clean file: {random_clean.name}")
print(f"Selected noisy file: {noisy_file.name}")
# Out:
# Selected clean file: p249_290.wav
# Selected noisy file: p249_290_confroom1_iPad_ch1.wav

# %%
# Load audio files
def load_audio(filepath, target_sr=16000):
    sr, audio = wavfile.read(filepath)
    # Convert to float32 and normalize
    if audio.dtype == np.int16:
        audio = audio.astype(np.float32) / 32768.0
    elif audio.dtype == np.int32:
        audio = audio.astype(np.float32) / 2147483648.0
    elif audio.dtype == np.float64:
        audio = audio.astype(np.float32)
    
    # Ensure mono
    if len(audio.shape) > 1:
        audio = audio.mean(axis=1)
    
    return audio, sr

clean_audio, sr_clean = load_audio(random_clean)
noisy_audio, sr_noisy = load_audio(noisy_file)

print(f"Clean audio: {len(clean_audio)} samples, {sr_clean} Hz, duration: {len(clean_audio)/sr_clean:.2f}s")
print(f"Noisy audio: {len(noisy_audio)} samples, {sr_noisy} Hz, duration: {len(noisy_audio)/sr_noisy:.2f}s")
# Out:
# Clean audio: 56537 samples, 16000 Hz, duration: 3.53s
# Noisy audio: 56537 samples, 16000 Hz, duration: 3.53s

# %%
# Make sure both audios have same length (use minimum)
min_len = min(len(clean_audio), len(noisy_audio))
clean_audio = clean_audio[:min_len]
noisy_audio = noisy_audio[:min_len]

print(f"Aligned length: {min_len} samples ({min_len/16000:.2f}s)")
# Out:
# Aligned length: 56537 samples (3.53s)

# %%
# Original Clean and Noisy Audio with Waveforms

# === CLEAN AUDIO ===
print("=" * 60)
print("ORIGINAL CLEAN AUDIO")
print("=" * 60)
display(Audio(clean_audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

# Full waveform - Clean
time_full = np.arange(len(clean_audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title('Full Waveform - CLEAN')
axes[0].grid(True, alpha=0.3)

# Zoomed waveform - Clean (100ms starting from 1 second = 1600 samples at 16kHz)
zoom_start = 16000  # 1 second
zoom_samples = 1600  # 100ms
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000  # Convert to ms, offset by 1000ms
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title('Zoomed (1000-1100ms) - CLEAN')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# === NOISY AUDIO ===
print("\n" + "=" * 60)
print("ORIGINAL NOISY AUDIO")
print("=" * 60)
display(Audio(noisy_audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

# Full waveform - Noisy
time_full = np.arange(len(noisy_audio)) / 16000
axes[0].plot(time_full, noisy_audio, linewidth=0.5, color='red')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title('Full Waveform - NOISY')
axes[0].grid(True, alpha=0.3)

# Zoomed waveform - Noisy
axes[1].plot(time_zoom, noisy_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='red')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title('Zoomed (1000-1100ms) - NOISY')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ============================================================
# ORIGINAL CLEAN AUDIO
# ============================================================
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ============================================================
# ORIGINAL NOISY AUDIO
# ============================================================
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Encode both audios with DAC
def encode_audio(model, audio, device):
    """Encode audio and return codes"""
    # Prepare input: [B, 1, T]
    audio_tensor = torch.from_numpy(audio).float().unsqueeze(0).unsqueeze(0).to(device)
    
    # Preprocess (padding)
    audio_tensor = model.preprocess(audio_tensor, sample_rate=16000)
    
    with torch.no_grad():
        z, codes, latents, _, _ = model.encode(audio_tensor)
    
    return codes, z

clean_codes, clean_z = encode_audio(model, clean_audio, device)
noisy_codes, noisy_z = encode_audio(model, noisy_audio, device)

print(f"Clean codes shape: {clean_codes.shape}")
print(f"Noisy codes shape: {noisy_codes.shape}")
print(f"\nCodes shape is [batch, n_codebooks, time_steps]")
print(f"Number of codebooks: {clean_codes.shape[1]}")
print(f"Number of time steps: {clean_codes.shape[2]}")
# Out:
# Clean codes shape: torch.Size([1, 12, 177])
# Noisy codes shape: torch.Size([1, 12, 177])
#
# Codes shape is [batch, n_codebooks, time_steps]
# Number of codebooks: 12
# Number of time steps: 177

# %%
# Function to create hybrid codes with CLEAN from END and decode
def create_hybrid_clean_from_end_and_decode(model, clean_codes, noisy_codes, n_clean_from_end, device):
    """
    Create hybrid codes where LAST n_clean_from_end codebooks are from CLEAN,
    and the FIRST (12-n_clean_from_end) are from NOISY.
    
    n_clean_from_end: 1 to 12
    - 1 means: [N, N, N, N, N, N, N, N, N, N, N, C] (last 1 clean)
    - 2 means: [N, N, N, N, N, N, N, N, N, N, C, C] (last 2 clean)
    - 12 means: [C, C, C, C, C, C, C, C, C, C, C, C] (all clean)
    """
    n_codebooks = clean_codes.shape[1]
    n_noisy = n_codebooks - n_clean_from_end
    
    # Create hybrid codes
    hybrid_codes = torch.zeros_like(clean_codes)
    
    # First n_noisy codebooks from NOISY
    hybrid_codes[:, :n_noisy, :] = noisy_codes[:, :n_noisy, :]
    
    # Last n_clean_from_end codebooks from CLEAN
    hybrid_codes[:, n_noisy:, :] = clean_codes[:, n_noisy:, :]
    
    # Decode using quantizer.from_codes
    with torch.no_grad():
        z_q, _, _ = model.quantizer.from_codes(hybrid_codes)
        decoded_audio = model.decode(z_q)
    
    return decoded_audio.squeeze().cpu().numpy(), hybrid_codes

# Test with one hybrid
test_audio, test_codes = create_hybrid_clean_from_end_and_decode(model, clean_codes, noisy_codes, 1, device)
print(f"Decoded audio shape: {test_audio.shape}")
# Out:
# Decoded audio shape: (56632,)

# %%
# Generate all 12 hybrid waveforms (clean from end)
n_codebooks = clean_codes.shape[1]
hybrid_audios = []

for n_clean_end in range(1, n_codebooks + 1):
    audio, codes = create_hybrid_clean_from_end_and_decode(model, clean_codes, noisy_codes, n_clean_end, device)
    hybrid_audios.append(audio)
    
    # Create label showing which codebooks are noisy (N) vs clean (C)
    n_noisy = n_codebooks - n_clean_end
    label = ['N'] * n_noisy + ['C'] * n_clean_end
    print(f"Hybrid {n_clean_end:2d}: {' '.join(label)}")

print(f"\nGenerated {len(hybrid_audios)} hybrid waveforms (clean from end)")

# Helper function to calculate metrics
def calculate_metrics(clean, generated):
    """Calculate MSE, SNR, and correlation between clean and generated audio"""
    # Ensure same length
    min_len = min(len(clean), len(generated))
    clean = clean[:min_len]
    generated = generated[:min_len]
    
    # MSE
    mse = np.mean((clean - generated) ** 2)
    
    # SNR (Signal-to-Noise Ratio in dB)
    signal_power = np.mean(clean ** 2)
    noise_power = np.mean((clean - generated) ** 2)
    if noise_power > 0:
        snr = 10 * np.log10(signal_power / noise_power)
    else:
        snr = float('inf')
    
    # Correlation
    corr = np.corrcoef(clean, generated)[0, 1]
    
    return mse, snr, corr

print("\n" + "=" * 60)
print("Reference: Metrics for Original Noisy vs Clean")
print("=" * 60)
mse_noisy, snr_noisy, corr_noisy = calculate_metrics(clean_audio, noisy_audio)
print(f"MSE: {mse_noisy:.6f} | SNR: {snr_noisy:.2f} dB | Correlation: {corr_noisy:.4f}")
# Out:
# Hybrid  1: N N N N N N N N N N N C
# Hybrid  2: N N N N N N N N N N C C
# Hybrid  3: N N N N N N N N N C C C
# Hybrid  4: N N N N N N N N C C C C
# Hybrid  5: N N N N N N N C C C C C
# Hybrid  6: N N N N N N C C C C C C
# Hybrid  7: N N N N N C C C C C C C
# Hybrid  8: N N N N C C C C C C C C
# Hybrid  9: N N N C C C C C C C C C
# Hybrid 10: N N C C C C C C C C C C
# Hybrid 11: N C C C C C C C C C C C
# Hybrid 12: C C C C C C C C C C C C
#
# Generated 12 hybrid waveforms (clean from end)
#
# ============================================================
# Reference: Metrics for Original Noisy vs Clean
# ============================================================
# MSE: 0.023259 | SNR: -6.81 dB | Correlation: 0.4855

# %% [markdown]
# ---
# ## Hybrid Waveform Analysis (Clean from End)
#
# Below are 12 cells, each showing:
# 1. Audio player
# 2. Full waveform plot (with clean overlay)
# 3. Zoomed waveform (1000-1100ms, with clean overlay)
#
# **Pattern**: Hybrid N has LAST N codebooks from CLEAN, FIRST (12-N) from NOISY

# %%
# Hybrid 1: [N, N, N, N, N, N, N, N, N, N, N, C] - 11 noisy, 1 clean at end
idx = 0
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

# Calculate metrics
mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 1: N N N N N N N N N N N C
# MSE: 0.025692 | SNR: -7.24 dB | Correlation: 0.3056
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 2: [N, N, N, N, N, N, N, N, N, N, C, C] - 10 noisy, 2 clean at end
idx = 1
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 2: N N N N N N N N N N C C
# MSE: 0.024661 | SNR: -7.06 dB | Correlation: 0.3042
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 3: [N, N, N, N, N, N, N, N, N, C, C, C] - 9 noisy, 3 clean at end
idx = 2
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 3: N N N N N N N N N C C C
# MSE: 0.023997 | SNR: -6.94 dB | Correlation: 0.3009
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 4: [N, N, N, N, N, N, N, N, C, C, C, C] - 8 noisy, 4 clean at end
idx = 3
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 4: N N N N N N N N C C C C
# MSE: 0.023230 | SNR: -6.80 dB | Correlation: 0.3073
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 5: [N, N, N, N, N, N, N, C, C, C, C, C] - 7 noisy, 5 clean at end
idx = 4
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 5: N N N N N N N C C C C C
# MSE: 0.022684 | SNR: -6.70 dB | Correlation: 0.3151
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 6: [N, N, N, N, N, N, C, C, C, C, C, C] - 6 noisy, 6 clean at end
idx = 5
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 6: N N N N N N C C C C C C
# MSE: 0.022000 | SNR: -6.57 dB | Correlation: 0.3423
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 7: [N, N, N, N, N, C, C, C, C, C, C, C] - 5 noisy, 7 clean at end
idx = 6
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 7: N N N N N C C C C C C C
# MSE: 0.021030 | SNR: -6.37 dB | Correlation: 0.3347
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 8: [N, N, N, N, C, C, C, C, C, C, C, C] - 4 noisy, 8 clean at end
idx = 7
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 8: N N N N C C C C C C C C
# MSE: 0.020040 | SNR: -6.16 dB | Correlation: 0.3349
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 9: [N, N, N, C, C, C, C, C, C, C, C, C] - 3 noisy, 9 clean at end
idx = 8
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 9: N N N C C C C C C C C C
# MSE: 0.019902 | SNR: -6.13 dB | Correlation: 0.3245
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 10: [N, N, C, C, C, C, C, C, C, C, C, C] - 2 noisy, 10 clean at end
idx = 9
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 10: N N C C C C C C C C C C
# MSE: 0.018978 | SNR: -5.92 dB | Correlation: 0.3031
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 11: [N, C, C, C, C, C, C, C, C, C, C, C] - 1 noisy, 11 clean at end
idx = 10
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)}")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end}')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 11: N C C C C C C C C C C C
# MSE: 0.015791 | SNR: -5.13 dB | Correlation: 0.2573
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Hybrid 12: [C, C, C, C, C, C, C, C, C, C, C, C] - 0 noisy, 12 clean (fully clean)
idx = 11
n_clean_end = idx + 1
n_noisy = n_codebooks - n_clean_end
label = ['N'] * n_noisy + ['C'] * n_clean_end
audio = hybrid_audios[idx][:min_len]

mse, snr, corr = calculate_metrics(clean_audio, audio)

print(f"Hybrid {n_clean_end}: {' '.join(label)} (Fully Clean Reconstruction)")
print(f"MSE: {mse:.6f} | SNR: {snr:.2f} dB | Correlation: {corr:.4f}")
display(Audio(audio, rate=16000))

fig, axes = plt.subplots(1, 2, figsize=(14, 3))

time_full = np.arange(len(audio)) / 16000
axes[0].plot(time_full, clean_audio, linewidth=0.5, color='green', alpha=0.7, label='Clean')
axes[0].plot(time_full, audio, linewidth=0.5, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[0].set_xlabel('Time (s)')
axes[0].set_ylabel('Amplitude')
axes[0].set_title(f'Full Waveform - Hybrid {n_clean_end} (All Clean)')
axes[0].legend(loc='upper right')
axes[0].grid(True, alpha=0.3)

zoom_start = 16000
zoom_samples = 1600
time_zoom = np.arange(zoom_samples) / 16000 * 1000 + 1000
axes[1].plot(time_zoom, clean_audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='green', alpha=0.7, label='Clean')
axes[1].plot(time_zoom, audio[zoom_start:zoom_start+zoom_samples], linewidth=1, color='blue', alpha=0.7, label=f'Hybrid {n_clean_end}')
axes[1].set_xlabel('Time (ms)')
axes[1].set_ylabel('Amplitude')
axes[1].set_title(f'Zoomed (1000-1100ms) - Hybrid {n_clean_end}')
axes[1].legend(loc='upper right')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Hybrid 12: C C C C C C C C C C C C (Fully Clean Reconstruction)
# MSE: 0.006938 | SNR: -1.55 dB | Correlation: 0.2750
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generate metrics JSON for all 5 files x 12 variants x 3 metrics (CLEAN FROM END)
import json

# Get all clean files
all_clean_files = sorted(list(clean_dir.glob("*.wav")))
print(f"Found {len(all_clean_files)} clean files")

results = {
    "experiment": "clean_from_end",
    "description": "LAST N codebooks from CLEAN, FIRST (12-N) from NOISY",
    "files": [],
    "metrics": ["mse", "snr", "correlation"],
    "n_variants": 12,
    "data": []  # Shape: [n_files, 12, 3]
}

for file_idx, clean_file in enumerate(all_clean_files):
    base_name = clean_file.stem
    noisy_file = list(noise_dir.glob(f"{base_name}*.wav"))[0]
    
    print(f"\nProcessing file {file_idx + 1}/5: {base_name}")
    results["files"].append(base_name)
    
    # Load audio
    clean_aud, _ = load_audio(clean_file)
    noisy_aud, _ = load_audio(noisy_file)
    
    # Align lengths
    min_length = min(len(clean_aud), len(noisy_aud))
    clean_aud = clean_aud[:min_length]
    noisy_aud = noisy_aud[:min_length]
    
    # Encode both
    clean_c, _ = encode_audio(model, clean_aud, device)
    noisy_c, _ = encode_audio(model, noisy_aud, device)
    
    # Generate 12 variants (clean from end) and calculate metrics
    file_metrics = []  # [12, 3]
    
    for n_clean_end in range(1, 13):
        hybrid_aud, _ = create_hybrid_clean_from_end_and_decode(model, clean_c, noisy_c, n_clean_end, device)
        hybrid_aud = hybrid_aud[:min_length]
        
        mse, snr, corr = calculate_metrics(clean_aud, hybrid_aud)
        file_metrics.append([float(mse), float(snr), float(corr)])
        
        n_noisy = 12 - n_clean_end
        label = ['N'] * n_noisy + ['C'] * n_clean_end
        print(f"  Variant {n_clean_end:2d} ({' '.join(label)}): MSE={mse:.6f}, SNR={snr:.2f}dB, Corr={corr:.4f}")
    
    results["data"].append(file_metrics)

# Convert to the exact shape requested: [5, 12, 3]
print(f"\n{'='*60}")
print(f"Results shape: [{len(results['data'])}, {len(results['data'][0])}, {len(results['data'][0][0])}]")
print(f"Files: {results['files']}")
print(f"Metrics order: {results['metrics']}")

# Save to JSON file
json_output_path = "../sample_data/codebook_metrics_clean_from_end.json"
with open(json_output_path, 'w') as f:
    json.dump(results, f, indent=2)

print(f"\nJSON saved to: {json_output_path}")

# Also display the JSON
print(f"\n{'='*60}")
print("JSON Output:")
print(json.dumps(results, indent=2))
# Out:
# Found 5 clean files
#
# Processing file 1/5: p249_290
#   Variant  1 (N N N N N N N N N N N C): MSE=0.025678, SNR=-7.24dB, Corr=0.3060
#   Variant  2 (N N N N N N N N N N C C): MSE=0.024687, SNR=-7.07dB, Corr=0.3051
#   Variant  3 (N N N N N N N N N C C C): MSE=0.024004, SNR=-6.94dB, Corr=0.3016
#   Variant  4 (N N N N N N N N C C C C): MSE=0.023250, SNR=-6.81dB, Corr=0.3081
#   Variant  5 (N N N N N N N C C C C C): MSE=0.022706, SNR=-6.70dB, Corr=0.3157
#   Variant  6 (N N N N N N C C C C C C): MSE=0.022023, SNR=-6.57dB, Corr=0.3424
#   Variant  7 (N N N N N C C C C C C C): MSE=0.021053, SNR=-6.37dB, Corr=0.3350
#   Variant  8 (N N N N C C C C C C C C): MSE=0.020089, SNR=-6.17dB, Corr=0.3348
#   Variant  9 (N N N C C C C C C C C C): MSE=0.019921, SNR=-6.13dB, Corr=0.3247
#   Variant 10 (N N C C C C C C C C C C): MSE=0.019016, SNR=-5.93dB, Corr=0.3030
#   Variant 11 (N C C C C C C C C C C C): MSE=0.015814, SNR=-5.13dB, Corr=0.2573
#   Variant 12 (C C C C C C C C C C C C): MSE=0.006950, SNR=-1.56dB, Corr=0.2746
#
# Processing file 2/5: p302_018
#   Variant  1 (N N N N N N N N N N N C): MSE=0.017499, SNR=-7.49dB, Corr=0.0762
#   Variant  2 (N N N N N N N N N N C C): MSE=0.016957, SNR=-7.35dB, Corr=0.0795
#   Variant  3 (N N N N N N N N N C C C): MSE=0.016462, SNR=-7.22dB, Corr=0.0877
#   Variant  4 (N N N N N N N N C C C C): MSE=0.016465, SNR=-7.22dB, Corr=0.0782
#   Variant  5 (N N N N N N N C C C C C): MSE=0.016315, SNR=-7.18dB, Corr=0.0724
#   Variant  6 (N N N N N N C C C C C C): MSE=0.016100, SNR=-7.12dB, Corr=0.0616
#   Variant  7 (N N N N N C C C C C C C): MSE=0.016186, SNR=-7.15dB, Corr=0.0536
#   Variant  8 (N N N N C C C C C C C C): MSE=0.016062, SNR=-7.11dB, Corr=0.0441
#   Variant  9 (N N N C C C C C C C C C): MSE=0.015998, SNR=-7.10dB, Corr=0.0320
#   Variant 10 (N N C C C C C C C C C C): MSE=0.013711, SNR=-6.43dB, Corr=0.0989
#   Variant 11 (N C C C C C C C C C C C): MSE=0.012013, SNR=-5.85dB, Corr=0.1060
#   Variant 12 (C C C C C C C C C C C C): MSE=0.005422, SNR=-2.40dB, Corr=0.1388
#
# Processing file 3/5: p333_331
#   Variant  1 (N N N N N N N N N N N C): MSE=0.028600, SNR=-10.93dB, Corr=0.0396
#   Variant  2 (N N N N N N N N N N C C): MSE=0.027996, SNR=-10.84dB, Corr=0.0133
#   Variant  3 (N N N N N N N N N C C C): MSE=0.027432, SNR=-10.75dB, Corr=0.0213
#   Variant  4 (N N N N N N N N C C C C): MSE=0.026865, SNR=-10.66dB, Corr=0.0188
#   Variant  5 (N N N N N N N C C C C C): MSE=0.026434, SNR=-10.59dB, Corr=-0.0086
#   Variant  6 (N N N N N N C C C C C C): MSE=0.026023, SNR=-10.52dB, Corr=-0.0153
#   Variant  7 (N N N N N C C C C C C C): MSE=0.024980, SNR=-10.34dB, Corr=0.0049
#   Variant  8 (N N N N C C C C C C C C): MSE=0.024371, SNR=-10.24dB, Corr=-0.0148
#   Variant  9 (N N N C C C C C C C C C): MSE=0.025072, SNR=-10.36dB, Corr=-0.0264
#   Variant 10 (N N C C C C C C C C C C): MSE=0.020667, SNR=-9.52dB, Corr=0.0085
#   Variant 11 (N C C C C C C C C C C C): MSE=0.017748, SNR=-8.86dB, Corr=-0.0341
#   Variant 12 (C C C C C C C C C C C C): MSE=0.005351, SNR=-3.65dB, Corr=-0.1529
#
# Processing file 4/5: p336_136
#   Variant  1 (N N N N N N N N N N N C): MSE=0.031347, SNR=-9.86dB, Corr=0.1951
#   Variant  2 (N N N N N N N N N N C C): MSE=0.029837, SNR=-9.65dB, Corr=0.2016
#   Variant  3 (N N N N N N N N N C C C): MSE=0.029494, SNR=-9.60dB, Corr=0.1950
#   Variant  4 (N N N N N N N N C C C C): MSE=0.028604, SNR=-9.47dB, Corr=0.1991
#   Variant  5 (N N N N N N N C C C C C): MSE=0.028668, SNR=-9.48dB, Corr=0.1807
#   Variant  6 (N N N N N N C C C C C C): MSE=0.028359, SNR=-9.43dB, Corr=0.1671
#   Variant  7 (N N N N N C C C C C C C): MSE=0.027537, SNR=-9.30dB, Corr=0.1718
#   Variant  8 (N N N N C C C C C C C C): MSE=0.026869, SNR=-9.19dB, Corr=0.1527
#   Variant  9 (N N N C C C C C C C C C): MSE=0.026068, SNR=-9.06dB, Corr=0.1570
#   Variant 10 (N N C C C C C C C C C C): MSE=0.024941, SNR=-8.87dB, Corr=0.1782
#   Variant 11 (N C C C C C C C C C C C): MSE=0.015974, SNR=-6.94dB, Corr=0.1178
#   Variant 12 (C C C C C C C C C C C C): MSE=0.006162, SNR=-2.80dB, Corr=0.0541
#
# Processing file 5/5: p341_017
#   Variant  1 (N N N N N N N N N N N C): MSE=0.017035, SNR=-6.98dB, Corr=0.1054
#   Variant  2 (N N N N N N N N N N C C): MSE=0.016439, SNR=-6.82dB, Corr=0.1092
#   Variant  3 (N N N N N N N N N C C C): MSE=0.016159, SNR=-6.75dB, Corr=0.1041
#   Variant  4 (N N N N N N N N C C C C): MSE=0.015850, SNR=-6.66dB, Corr=0.1008
#   Variant  5 (N N N N N N N C C C C C): MSE=0.015567, SNR=-6.59dB, Corr=0.0980
#   Variant  6 (N N N N N N C C C C C C): MSE=0.015482, SNR=-6.56dB, Corr=0.0808
#   Variant  7 (N N N N N C C C C C C C): MSE=0.014726, SNR=-6.35dB, Corr=0.0899
#   Variant  8 (N N N N C C C C C C C C): MSE=0.014122, SNR=-6.16dB, Corr=0.0915
#   Variant  9 (N N N C C C C C C C C C): MSE=0.013724, SNR=-6.04dB, Corr=0.0749
#   Variant 10 (N N C C C C C C C C C C): MSE=0.012447, SNR=-5.62dB, Corr=0.0853
#   Variant 11 (N C C C C C C C C C C C): MSE=0.010266, SNR=-4.78dB, Corr=0.1123
#   Variant 12 (C C C C C C C C C C C C): MSE=0.005480, SNR=-2.05dB, Corr=0.1888
#
# ============================================================
# Results shape: [5, 12, 3]
# Files: ['p249_290', 'p302_018', 'p333_331', 'p336_136', 'p341_017']
# Metrics order: ['mse', 'snr', 'correlation']
#
# JSON saved to: ../sample_data/codebook_metrics_clean_from_end.json
#
# ============================================================
# JSON Output:
# {
#   "experiment": "clean_from_end",
#   "description": "LAST N codebooks from CLEAN, FIRST (12-N) from NOISY",
#   "files": [
#     "p249_290",
#     "p302_018",
#     "p333_331",
#     "p336_136",
#     "p341_017"
#   ],
#   "metrics": [
#     "mse",
#     "snr",
#     "correlation"
#   ],
#   "n_variants": 12,
#   "data": [
#     [
#       [
#         0.025677932426333427,
#         -7.237161636352539,
#         0.30601024030830287
#       ],
#       [
#         0.02468666061758995,
#         -7.066184043884277,
#         0.30514658123321214
#       ],
#       [
#         0.02400416135787964,
#         -6.944426536560059,
#         0.30159146019515165
#       ],
#       [
#         0.02325000986456871,
#         -6.805792331695557,
#         0.3080989505189771
#       ],
#       [
#         0.022705990821123123,
#         -6.70296573638916,
#         0.31566678681008614
#       ],
#       [
#         0.022023236379027367,
#         -6.570372104644775,
#         0.3423755673579647
#       ],
#       [
#         0.021053051576018333,
#         -6.374711513519287,
#         0.3349747922798654
#       ],
#       [
#         0.020089048892259598,
#         -6.171154975891113,
#         0.3348179018737924
#       ],
#       [
#         0.019920773804187775,
#         -6.1346235275268555,
#         0.3246749552602216
#       ],
#       [
#         0.019015679135918617,
#         -5.932679176330566,
#         0.302996420702023
#       ],
#       [
#         0.015814051032066345,
#         -5.131992340087891,
#         0.25731771543766746
#       ],
#       [
#         0.00695014838129282,
#         -1.5615015029907227,
#         0.2745958864683766
#       ]
#     ],
#     [
#       [
#         0.01749938726425171,
#         -7.485174655914307,
#         0.07624972246189123
#       ],
#       [
#         0.016957106068730354,
#         -7.348463535308838,
#         0.07950889703420322
#       ],
#       [
#         0.016461815685033798,
#         -7.219724178314209,
#         0.08769897899058297
#       ],
#       [
#         0.0164654403924942,
#         -7.220680236816406,
#         0.07819545236959419
#       ],
#       [
#         0.016314588487148285,
#         -7.1807074546813965,
#         0.07242763840542997
#       ],
#       [
#         0.016100144013762474,
#         -7.123243808746338,
#         0.06162028186283265
#       ],
#       [
#         0.016185984015464783,
#         -7.146337509155273,
#         0.05363280140390275
#       ],
#       [
#         0.016062317416071892,
#         -7.113028049468994,
#         0.044090870421170665
#       ],
#       [
#         0.01599840633571148,
#         -7.0957136154174805,
#         0.03196012530530379
#       ],
#       [
#         0.01371137984097004,
#         -6.425757884979248,
#         0.09888935831942991
#       ],
#       [
#         0.012013224884867668,
#         -5.8515424728393555,
#         0.10602471557128719
#       ],
#       [
#         0.005422079004347324,
#         -2.3966047763824463,
#         0.13879367306431747
#       ]
#     ],
#     [
#       [
#         0.028600314632058144,
#         -10.93046760559082,
#         0.03959639128201858
#       ],
#       [
#         0.027995510026812553,
#         -10.837642669677734,
#         0.013336867548025128
#       ],
#       [
#         0.027431637048721313,
#         -10.749277114868164,
#         0.021288823889247938
#       ],
#       [
#         0.02686455100774765,
#         -10.65855598449707,
#         0.018778014285781082
#       ],
#       [
#         0.026434363797307014,
#         -10.588447570800781,
#         -0.008621146340112943
#       ],
#       [
#         0.026022927835583687,
#         -10.520320892333984,
#         -0.015257198250425676
#       ],
#       [
#         0.024979954585433006,
#         -10.342676162719727,
#         0.004896235948004732
#       ],
#       [
#         0.024371085688471794,
#         -10.235508918762207,
#         -0.014763889839336459
#       ],
#       [
#         0.025071829557418823,
#         -10.358620643615723,
#         -0.026364858650576282
#       ],
#       [
#         0.020666688680648804,
#         -9.519468307495117,
#         0.008497215835787837
#       ],
#       [
#         0.017747536301612854,
#         -8.858139991760254,
#         -0.03413548313567913
#       ],
#       [
#         0.005350697319954634,
#         -3.6508631706237793,
#         -0.15292569918350576
#       ]
#     ],
#     [
#       [
#         0.03134714066982269,
#         -9.863222122192383,
#         0.19512220945599262
#       ],
#       [
#         0.029836788773536682,
#         -9.648763656616211,
#         0.20164658566183094
#       ],
#       [
#         0.029493719339370728,
#         -9.598539352416992,
#         0.19501582785275073
#       ],
#       [
#         0.0286041758954525,
#         -9.465538024902344,
#         0.1990944037481927
#       ],
#       [
#         0.028668301180005074,
#         -9.475262641906738,
#         0.18074903332847428
#       ],
#       [
#         0.028359388932585716,
#         -9.42821216583252,
#         0.1670984774591617
#       ],
#       [
#         0.027537239715456963,
#         -9.300447463989258,
#         0.17180655786433122
#       ],
#       [
#         0.02686876244843006,
#         -9.193719863891602,
#         0.15271821286147555
#       ],
#       [
#         0.02606823854148388,
#         -9.062359809875488,
#         0.15699997365843216
#       ],
#       [
#         0.0249409731477499,
#         -8.870376586914062,
#         0.17822482556699093
#       ],
#       [
#         0.015973566100001335,
#         -6.935262203216553,
#         0.11775032414376037
#       ],
#       [
#         0.006162444595247507,
#         -2.798773765563965,
#         0.05410350909168998
#       ]
#     ],
#     [
#       [
#         0.01703491434454918,
#         -6.977601051330566,
#         0.10544548712572747
#       ],
#       [
#         0.016439015045762062,
#         -6.822958946228027,
#         0.10922222552168796
#       ],
#       [
#         0.016159256920218468,
#         -6.748414993286133,
#         0.10406065063474199
#       ],
#       [
#         0.01585000939667225,
#         -6.664496421813965,
#         0.10080105616103939
#       ],
#       [
#         0.015567255206406116,
#         -6.586321830749512,
#         0.09795231337218234
#       ],
#       [
#         0.01548150833696127,
#         -6.562334060668945,
#         0.08081733935240751
#       ],
#       [
#         0.014726255089044571,
#         -6.345124244689941,
#         0.0898558592162495
#       ],
#       [
#         0.01412182953208685,
#         -6.163110733032227,
#         0.09149256975691168
#       ],
#       [
#         0.013724272139370441,
#         -6.039094924926758,
#         0.07485382136713246
#       ],
#       [
#         0.012447463348507881,
#         -5.615009784698486,
#         0.08530179125186907
#       ],
#       [
#         0.01026616245508194,
#         -4.778282642364502,
#         0.11225223904616212
#       ],
#       [
#         0.005480061750859022,
#         -2.052055835723877,
#         0.18882976040387703
#       ]
#     ]
#   ]
# }
